# %%
! pip install datasets
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 1.3 MB/s eta 0:00:0000:0100:01m
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ...

# %%
from datasets import  load_dataset

# %%
import pandas as pd

# %%
data = load_dataset("csebuetnlp/xlsum", "telugu")
# Out:
# 0000.parquet:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/4.96M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/1302 [00:00<?, ? examples/s]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'url', 'title', 'summary', 'text'],
#         num_rows: 10421
#     })
#     test: Dataset({
#         features: ['id', 'url', 'title', 'summary', 'text'],
#         num_rows: 1302
#     })
#     validation: Dataset({
#         features: ['id', 'url', 'title', 'summary', 'text'],
#         num_rows: 1302
#     })
# })

# %%
train_df = pd.DataFrame(data['train'])
valid_df = pd.DataFrame(data['validation'])
test_df = pd.DataFrame(data['test'])

# %%
train_df.head()
